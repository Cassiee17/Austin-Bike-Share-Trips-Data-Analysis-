# %%
import pandas as pd

# %%
stations=pd.read_csv('/Users/mingyuan.xu/Desktop/archive-6/austin_bikeshare_stations.csv')
trips=pd.read_csv('/Users/mingyuan.xu/Desktop/archive-6/austin_bikeshare_trips.csv')

# %%
stations.head()
# Out:
#    latitude              location  longitude                     name  \
# 0  30.27041  (30.27041 -97.75046)  -97.75046           West & 6th St.
# 1  30.26452   (30.26452 -97.7712)  -97.77120      Barton Springs Pool
# 2  30.27595  (30.27595 -97.74739)  -97.74739  ACC - Rio Grande & 12th
# 3  30.28480   (30.2848 -97.72756)  -97.72756  Red River & LBJ Library
# 4  30.26694  (30.26694 -97.74939)  -97.74939             Nueces @ 3rd
#
#    station_id  status
# 0        2537  active
# 1        2572  active
# 2        2545  closed
# 3        1004  closed
# 4        1008   moved

# %% [markdown]
# This dataset includes the information of positions of bike share station, and the correspongding station status.

# %% [markdown]
# **Uniqueness Check:**\
# First, we check the uniqueness of this dataset. Since the station_id should be unique, we use this information to check.

# %%
len(stations['station_id'].unique())==stations.shape[0]
# Out:
# True

# %% [markdown]
# It can be seen that the number of unique station_id is equal to the number of rows of this dataset. Therefore, there is no repeated data in this dataset.

# %% [markdown]
# **Missing Data Check:**\
# Next, we check whether there are some missing data in this dataset.

# %%
pd.isnull(stations).any()
# Out:
# latitude      False
# location      False
# longitude     False
# name          False
# station_id    False
# status        False
# dtype: bool

# %% [markdown]
# It can be seen that there is **no** missing data in this dataset.

# %%
stations['status'].value_counts()
# Out:
# active      56
# closed      10
# moved        5
# ACL only     1
# Name: status, dtype: int64

# %% [markdown]
# As for the status of stations, there are 56 active stations, 10 closed stations, and 5 moved stations, and 1 ACL only (active only during Austin City Limits Music Festival).

# %% [markdown]
# Now, since the dataset provides the latitude and longitude of stations, we can create a map.

# %%
import folium
from folium import plugins
from folium import Choropleth, Circle, Marker
import seaborn as sns
from folium.plugins import HeatMap

# %%
active_stations=stations[stations.status=='active']
closed_stations=stations[stations.status=='closed']
moved_stations=stations[stations.status=='moved']
acl_stations=stations[stations.status=='ACL only']   #divide the stations into 4 groups based on their status

# %%
stations.describe()
# Out:
#         latitude  longitude   station_id
# count  72.000000  72.000000    72.000000
# mean   30.266822 -97.742937  2625.055556
# std     0.007811   0.012681   708.966633
# min    30.248910 -97.771200  1001.000000
# 25%    30.262128 -97.749315  2503.750000
# 50%    30.266955 -97.743200  2562.500000
# 75%    30.270573 -97.738360  2940.000000
# max    30.285760 -97.710020  3687.000000

# %% [markdown]
# From the table above, we can used the means of latitude and longitude as the center position of our map.\
# **latitude:30.266822, longitude:-97.742937**\
# **Active:Blue\
# Closed:Red\
# Moved:Green\
# ACL only:Pink**

# %%
lat=30.266822
lon=-97.742937

whole_map=folium.Map(location=[lat, lon],zoom_start=14,control_scale=True)


for lat,lon,label in zip(active_stations.latitude,active_stations.longitude,active_stations.name):
    folium.Marker(location=[lat,lon],icon=folium.Icon(color='blue', icon='cloud'),
                  popup=label).add_to(whole_map)

for lat,lon,label in zip(closed_stations.latitude,closed_stations.longitude,closed_stations.name):
    folium.Marker(location=[lat,lon],icon=folium.Icon(color='red', icon='cloud'),
                  popup=label).add_to(whole_map)

for lat,lon,label in zip(moved_stations.latitude,moved_stations.longitude,moved_stations.name):
    folium.Marker(location=[lat,lon],icon=folium.Icon(color='green', icon='cloud'),
                  popup=label).add_to(whole_map)

folium.Marker(location=[acl_stations.latitude,acl_stations.longitude],icon=folium.Icon(color='pink', icon='cloud'),
              popup=label).add_to(whole_map)

whole_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b695ee9a07fc629b991f8d8a83a7360 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b695ee9a07fc629b991f8d8a83a7360&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b695ee9a07fc629b991f8d8a83a7360 = L.map(
#                 &quot;map_5b695ee9a07fc629b991f8d8a83a7360&quot;,
#                 {
#                     center: [30.266822, -97.742937],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#
#
#
#             var tile_layer_4a84b750665fa228c73e12a310c2be95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#             var marker_7030232c8e8e8d271f6ec18b53657931 = L.marker(
#                 [30.27041, -97.75046],
#                 {}
#             ).addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#             var icon_64d3cc3d1b7b3cdee6cf98259394bd66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7030232c8e8e8d271f6ec18b53657931.setIcon(icon_64d3cc3d1b7b3cdee6cf98259394bd66);
#
#
#         var popup_64e6b76e037569b5c5a8e4481fbe9b99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_041d34b8f90bafe9b69b9b7ad2460369 = $(`&lt;div id=&quot;html_041d34b8f90bafe9b69b9b7ad2460369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;West &amp; 6th St.&lt;/div&gt;`)[0];
#                 popup_64e6b76e037569b5c5a8e4481fbe9b99.setContent(html_041d34b8f90bafe9b69b9b7ad2460369);
#
#
#
#         marker_7030232c8e8e8d271f6ec18b53657931.bindPopup(popup_64e6b76e037569b5c5a8e4481fbe9b99)
#         ;
#
#
#
#
#             var marker_2430a7bbec373e6881de3f33f2d67c6d = L.marker(
#                 [30.26452, -97.7712],
#                 {}
#             ).addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#             var icon_e0058ca5d65aa520a7a9697e1b9be91e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2430a7bbec373e6881de3f33f2d67c6d.setIcon(icon_e0058ca5d65aa520a7a9697e1b9be91e);
#
#
#         var popup_b9fb207c2782e6bed580df6d96c87304 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32cfc88f5aa8390faf9427ad5c4e5fde = $(`&lt;div id=&quot;html_32cfc88f5aa8390faf9427ad5c4e5fde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barton Springs Pool&lt;/div&gt;`)[0];
#                 popup_b9fb207c2782e6bed580df6d96c87304.setContent(html_32cfc88f5aa8390faf9427ad5c4e5fde);
#
#
#
#         marker_2430a7bbec373e6881de3f33f2d67c6d.bindPopup(popup_b9fb207c2782e6bed580df6d96c87304)
#         ;
#
#
#
#
#             var marker_cc4ee42bd3487e8a13610e31822d34cb = L.marker(
#                 [30.24891, -97.75019],
#                 {}
#             ).addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#             var icon_3be0878fede53e5548f8541fb62146bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc4ee42bd3487e8a13610e31822d34cb.setIcon(icon_3be0878fede53e5548f8541fb62146bc);
#
#
#         var popup_3ec9ea4ab6a4ee15eeb415402bd4c385 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fe6727fd4aa8c18d394afb795a71c73 = $(`&lt;div id=&quot;html_3fe6727fd4aa8c18d394afb795a71c73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;South Congress &amp; Elizabeth&lt;/div&gt;`)[0];
#                 popup_3ec9ea4ab6a4ee15eeb415402bd4c385.setContent(html_3fe6727fd4aa8c18d394afb795a71c73);
#
#
#
#         marker_cc4ee42bd3487e8a13610e31822d34cb.bindPopup(popup_3ec9ea4ab6a4ee15eeb415402bd4c385)
#         ;
#
#
#
#
#             var marker_368210ab7ab60bf8c5dbf25a655ec5f4 = L.marker(
#                 [30.26217, -97.72743],
#                 {}
#             ).addTo(map_5b695ee9a07fc629b991f8d8a83a7360);
#
#
#             var icon_10bbb63edb901d90288bca6fd771ca3a = L.AwesomeMarkers.icon(

# %% [markdown]
# From this map, it can be seen that most of the active stations are highly distributed among downtown, which locates on the north bank of the Colorado River. Also, most of them are distributed along the streets and at the intersections of streets. They avoid being located along the US 290, which is a highway. Setting stations here will cause  waste of resources. In addition, there are some stations near the communal facilities, such as school and Capitol Square. **(Here the map cannot be shown in .ipynb on the website of github, so I upload the screenshot, map of all the stations.jpeg)**

# %% [markdown]
# As for the moved station, in the highly distributed region, downtown, three of them are located near other stations. Also, the other two located in the region with fewer stations. The reason of being moved maybe the avoidance of oversupply.

# %% [markdown]
# We can then focus on the active stations and use the **heat map** to reveal the distribution of active stations.

# %%
active_stations.describe() #still use the mean of latitude and longitude as the center of this map.
# Out:
#         latitude  longitude   station_id
# count  56.000000  56.000000    56.000000
# mean   30.266038 -97.743419  2794.982143
# std     0.007607   0.012476   567.016193
# min    30.248910 -97.771200  1001.000000
# 25%    30.260287 -97.749830  2538.750000
# 50%    30.266655 -97.743200  2567.500000
# 75%    30.269710 -97.738885  3293.250000
# max    30.285760 -97.710070  3687.000000

# %%
active_map=folium.Map(location=[30.266038,-97.743419],zoom_start=13,tiles='Stamen Toner', no_touch=True)
HeatMap(data=active_stations[['latitude','longitude']],radius=15).add_to(active_map)
active_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e49be4ac7b987c895026475383c7524 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e49be4ac7b987c895026475383c7524&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e49be4ac7b987c895026475383c7524 = L.map(
#                 &quot;map_3e49be4ac7b987c895026475383c7524&quot;,
#                 {
#                     center: [30.266038, -97.743419],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6a59478a9278a231edeca5b3cd937c1 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e49be4ac7b987c895026475383c7524);
#
#
#             var heat_map_e581d1c83537c91bf94d8e754631dd27 = L.heatLayer(
#                 [[30.27041, -97.75046], [30.26452, -97.7712], [30.24891, -97.75019], [30.26217, -97.72743], [30.285759999999996, -97.74181], [30.273359999999997, -97.73805], [30.26735, -97.73933000000001], [30.26717, -97.75484], [30.26854, -97.73646], [30.25579, -97.73982], [30.269109999999998, -97.7462], [30.274659999999997, -97.77028], [30.258390000000002, -97.74592], [30.26697, -97.74929], [30.26332, -97.74508], [30.272170000000003, -97.75246], [30.264059999999997, -97.76385], [30.25103, -97.74925999999999], [30.2659, -97.76822], [30.26912, -97.73986], [30.252259999999996, -97.74854], [30.264459999999996, -97.75665], [30.271929999999998, -97.73854], [30.267529999999997, -97.74805], [30.268890000000003, -97.74525], [30.25895, -97.71475], [30.26032, -97.71899], [30.259870000000003, -97.72373], [30.25542, -97.71665], [30.271859999999997, -97.73997], [30.25971, -97.75346], [30.26455, -97.73165], [30.26483, -97.73899999999999], [30.264259999999997, -97.74023000000001], [30.26019, -97.73845], [30.268959999999996, -97.72843], [30.269679999999997, -97.73074], [30.2587, -97.74871999999999], [30.261999999999997, -97.76118000000001], [30.2698, -97.74186], [30.2726, -97.74127], [30.26476, -97.74678], [30.25941, -97.74971], [30.28118, -97.75219], [30.28039, -97.73809], [30.279740000000004, -97.74254], [30.2563, -97.71007], [30.267540000000004, -97.74154], [30.26822, -97.74285], [30.276159999999997, -97.74488000000001], [30.25457, -97.74258], [30.26408, -97.74355], [30.266340000000003, -97.74378], [30.2678, -97.75189], [30.2696, -97.75332], [30.27654, -97.74155]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             ).addTo(map_3e49be4ac7b987c895026475383c7524);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From this heat map, it can be seen that most of the active stations are distributed among downtown, which locates at the north bank of the river. In addition, at the south bank of this river, there are also two regions with high density.**(Here the map cannot be shown in .ipynb on the website of github, so I upload the screenshot, heat map of active stations.jpeg)**
